# %%
import torch
import numpy as np

# %%
inpu = np.array([[74, 66, 43], 
                   [91, 87, 65], 
                   [88, 134, 59], 
                   [101, 44, 37], 
                   [68, 96, 71]], dtype='float32')

# %%
target = np.array([[57, 69], 
                    [80, 102], 
                    [118, 132], 
                    [21, 38], 
                    [104, 118]] , dtype='float32')

# %%
inputs = torch.from_numpy(inpu)
targets = torch.from_numpy(target)
w = torch.randn(2,3, requires_grad=True)
b = torch.randn(2, requires_grad=True)
print(w)
print(b)
print(inputs)
print(targets)
# Out:
# tensor([[-1.3937,  0.2694,  1.5425],
#         [ 0.3636,  0.2286,  0.2398]], requires_grad=True)
# tensor([ 0.3980, -0.5437], requires_grad=True)
# tensor([[ 74.,  66.,  43.],
#         [ 91.,  87.,  65.],
#         [ 88., 134.,  59.],
#         [101.,  44.,  37.],
#         [ 68.,  96.,  71.]])
# tensor([[ 57.,  69.],
#         [ 80., 102.],
#         [118., 132.],
#         [ 21.,  38.],
#         [104., 118.]])

# %%
prediction = inputs @ w.t() + b
print(prediction)
# Out:
# tensor([[-18.6269,  51.7629],
#         [ -2.7271,  68.0210],
#         [  4.8582,  76.2368],
#         [-71.4365,  55.1109],
#         [ 41.0064,  63.1552]], grad_fn=<AddBackward0>)

# %%
def mes(t1,t2):
    diff = t1-t2
    diff_sq = diff * diff
    mean_diff = torch.sum(diff_sq) / diff.numel()
    return mean_diff

# %%
loss=mes(prediction,targets)
print(loss)
loss.backward()
# Out:
# tensor(4573.8911, grad_fn=<DivBackward0>)

# %%
with torch.no_grad():
    w -= w.grad * 1e-5
    b -= b.grad * 1e-5
    w.grad.zero_()
    b.grad.zero_()

# %%
w
# Out:
# tensor([[-1.3203,  0.3443,  1.5889],
#         [ 0.3861,  0.2608,  0.2588]], requires_grad=True)

# %%
import torch
import numpy as np

inpu = np.array([[74, 66, 43], 
                   [91, 87, 65], 
                   [88, 134, 59], 
                   [101, 44, 37], 
                   [68, 96, 71]], dtype='float32')

target = np.array([[57, 69], 
                    [80, 102], 
                    [118, 132], 
                    [21, 38], 
                    [104, 118]] , dtype='float32')

inputs = torch.from_numpy(inpu)
targets = torch.from_numpy(target)
w = torch.randn(2,3, requires_grad=True)
b = torch.randn(2, requires_grad=True)

def mes(t1,t2):
    diff = t1-t2
    diff_sq = diff * diff
    mean_diff = torch.sum(diff_sq) / diff.numel()
    return mean_diff

# %%
target
# Out:
# array([[ 57.,  69.],
#        [ 80., 102.],
#        [118., 132.],
#        [ 21.,  38.],
#        [104., 118.]], dtype=float32)

# %%
prediction
# Out:
# tensor([[-18.6269,  51.7629],
#         [ -2.7271,  68.0210],
#         [  4.8582,  76.2368],
#         [-71.4365,  55.1109],
#         [ 41.0064,  63.1552]], grad_fn=<AddBackward0>)

# %%
for i in range(100):
    prediction = inputs @ w.t() + b
    loss=mes(prediction,targets)
    loss.backward()
    with torch.no_grad():
        w -= w.grad * 1e-5
        b -= b.grad * 1e-5
        w.grad.zero_()
        b.grad.zero_()

# %%
loss=mes(prediction,targets)

# %%
print(loss)
# Out:
# tensor(52.0424, grad_fn=<DivBackward0>)

# %%
import torch
import numpy as np
import torch.nn as nn

input_hour = np.array([2.5,
5.1,
3.2,
8.5,
3.5,
1.5,
9.2,
5.5,
8.3,
2.7,
7.7,
5.9,
4.5,
3.3,
1.1,
8.9,
2.5,
1.9,
6.1,
7.4,
2.7,
4.8,
3.8,
6.9,
7.8],dtype='float32')

target = np.array([21
,47
,27
,75
,30
,20
,88
,60
,81
,25
,85
,62
,41
,42
,17
,95
,30
,24
,67
,69
,30
,54
,35
,76
,86],dtype='float32')

input_tensor = torch.from_numpy(input_hour)

target_tensor = torch.from_numpy(target)
# Out:
# 25

# %%
from torch.utils.data import TensorDataset

# %%
train_ds = TensorDataset(input_tensor, target_tensor)
train_ds[0:3]
# Out:
# (tensor([2.5000, 5.1000, 3.2000]), tensor([21., 47., 27.]))

# %%
from torch.utils.data import DataLoader

# %%
batch_size = 5
train_dl = DataLoader(train_ds, batch_size, shuffle=True)

# %%
for xb, yb in train_dl:
    xb.size
    print(yb)
    break
# Out:
# tensor([81., 21., 30., 42., 41.])

# %%
model = nn.Linear(5,1)
print(model.weight)
print(model.bias)
# Out:
# Parameter containing:
# tensor([[-0.3001, -0.1948, -0.2711, -0.3863,  0.0441]], requires_grad=True)
# Parameter containing:
# tensor([-0.0523], requires_grad=True)

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.3001, -0.1948, -0.2711, -0.3863,  0.0441]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.0523], requires_grad=True)]

# %%
import torch.nn.functional as F

# %%
loss_fn = F.mse_loss

# %%
opt = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
# Utility function to train the model
def fit(num_epochs, model, loss_fn, opt, train_dl):
    
    # Repeat for given number of epochs
    for epoch in range(num_epochs):
        
        # Train with batches of data
        for xb,yb in train_dl:
            
            # 1. Generate predictions
            pred = model(xb)
            
            # 2. Calculate loss
            loss = loss_fn(pred, yb)
            
            # 3. Compute gradients
            loss.backward()
            
            # 4. Update parameters using gradients
            opt.step()
            
            # 5. Reset the gradients to zero
            opt.zero_grad()
        
        # Print the progress
        if (epoch+1) % 10 == 0:
            print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))

# %%
fit(100, model, loss_fn, opt, train_dl)
# Out:
# <ipython-input-93-28634c17ad42>:14: UserWarning: Using a target size (torch.Size([5])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss = loss_fn(pred, yb)
# Epoch [10/100], Loss: 611.2450
# Epoch [20/100], Loss: 409.3231
# Epoch [30/100], Loss: 630.5553
# Epoch [40/100], Loss: 931.0721
# Epoch [50/100], Loss: 853.9985
# Epoch [60/100], Loss: 457.4259
# Epoch [70/100], Loss: 544.0709
# Epoch [80/100], Loss: 728.7988
# Epoch [90/100], Loss: 417.0885
# Epoch [100/100], Loss: 429.0451
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Dell\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Dell\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
# ...

# %%
# Out:
# tensor([[ 55.0146,  69.4841],
#         [ 87.4622,  95.4515],
#         [106.1580, 141.6892],
#         [ 19.7252,  41.9592],
#         [113.5026, 109.2841]], grad_fn=<AddBackward0>)
